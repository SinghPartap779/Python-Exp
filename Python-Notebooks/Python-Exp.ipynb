# %%
tup = (7, 8, 9, 10, 11, 12)
print(type(tup))   # <class 'tuple'>
print(min(tup))    # 7
print(max(tup))    # 12
# Out:
# <class 'tuple'>
# 7
# 12

# %%
tup = (7, 8.8, 'PS')
number, float, string = tup
print(number)  # 7
print(float)   # 8.8
print(string)  # PS
# Out:
# 7
# 8.8
# PS
