# %%
tup = (7, 8, 9, 10, 11, 12)
print(type(tup))   # <class 'tuple'>
print(min(tup))    # 7
print(max(tup))    # 12
# Out:
# <class 'tuple'>
# 7
# 12

# %%
# Ask user to enter numbers separated by spaces
numbers = list(map(int, input("Enter numbers separated by space: ").split()))

# Ask user to enter names separated by spaces
names = input("Enter names separated by space: ").split()

# Combine both lists
mix = numbers + names

# Append a new name dynamically
new_name = input("Enter a name to add: ")
names.append
