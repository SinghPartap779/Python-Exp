# %% [markdown]
# # 02 Operators

# %% [markdown]
# ## Definition
# This notebook contains theory, examples, use cases, exercises, and interview questions.

# %%
print("Sample example for learning")

# %% [markdown]
# ## Practice Exercise
#
# 1. Try modifying the example.
# 2. Predict the output.
# 3. Create your own example.

# %% [markdown]
# ## Interview Questions
#
# - What is this concept?
# - When would you use it?
# - Give a practical example.
